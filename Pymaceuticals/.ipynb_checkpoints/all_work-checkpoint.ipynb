# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

import warnings
warnings.filterwarnings('ignore')

mouse_drug_data_to_load = "../../Homework/Instructions/Pymaceuticals/data/mouse_drug_data.csv"
clinical_trial_data_to_load = "../../Homework/Instructions/Pymaceuticals/data/clinicaltrial_data.csv"

mouse_drug_data_df = pd.read_csv(mouse_drug_data_to_load)
clinical_trial_data_df = pd.read_csv(clinical_trial_data_to_load)

# %%
mouse_clinic_df = pd.merge(mouse_drug_data_df, clinical_trial_data_df, on="Mouse ID")

# %%
all_drug_plots = []

all_drugs = mouse_clinic_df['Drug'].unique()

def treatments(list_drugs):
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        means = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
        sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]

        x_axis = drug_df['Timepoint'].unique()
        standard_errors = [sem(s) for s in sample]

        fig, ax = plt.subplots()
        ax.errorbar(x_axis, means, standard_errors, fmt="o")
        ax.set_xlabel("Timepoint")
        ax.set_ylabel("Tumor Volume (mm3)")
        ax.set_title(f"Effects of {drug} on Test Subjects")
    return all_drug_plots

# %%
treatments(all_drugs)
# Out:
# []

# %%
stelasyn_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == "Stelasyn"]

x_axis = stelasyn_df["Timepoint"]
y_axis = stelasyn_df["Tumor Volume (mm3)"]

# stelasyn_plot = plt.scatter(x_axis, y_axis, marker=".",facecolors="blue")

# %%
all_drug_plots = []

all_drugs = mouse_clinic_df['Drug'].unique()

def treatments(list_drugs):
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        drug_plot = drug_df.plot(kind="scatter", x="Timepoint", y="Tumor Volume (mm3)", grid=True,
                                 figsize=(10,10), title=(f"Effects of {(drug)} on Test Subjects"))
    return all_drug_plots

# treatments(all_drugs)

# %%
all_drug_plots = []

all_drugs = mouse_clinic_df['Drug'].unique()

def treatments(list_drugs):
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        x_axis = drug_df["Timepoint"]
        y_axis = drug_df["Tumor Volume (mm3)"]
        
        div = 20
        lim = len(drug_df) // div
        samples = [drug_df.iloc[(i * div):(i * div + div), 0] for i in range(0, lim)]
#         samples = drug_df["Tumor Volume (mm3)"]
#         standard_errors = [sem(s) for s in samples]

        fig, ax = plt.subplots()
        ax.errorbar(x_axis, y_axis, fmt="o")
        ax.set_xlabel("Timepoint")
        ax.set_ylabel("Tumor Volume (mm3)")
        ax.set_title(f"Effects of {drug} on Test Subjects")
    return all_drug_plots

# %%
treatments(all_drugs)
# Out:
# []

# %%
mouse_clinic_df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %%
capomulin_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == 'Capomulin']

times = capomulin_df['Timepoint'].unique()

means = [capomulin_df.loc[capomulin_df['Timepoint'] == (time)]['Metastatic Sites'].mean() for time in times]
sample = [capomulin_df.loc[capomulin_df['Timepoint'] == (time)]['Metastatic Sites'] for time in times]

x_axis = capomulin_df['Timepoint'].unique()
standard_errors = [sem(s) for s in sample]

fig, ax = plt.subplots()
ax.errorbar(x_axis, means, standard_errors, fmt="o")
ax.set_xlabel("Timepoint")
ax.set_ylabel("Metastic Sites")
# Out:
# Text(0, 0.5, 'Metastic Sites')
