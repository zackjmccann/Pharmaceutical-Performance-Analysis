# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

import warnings
warnings.filterwarnings('ignore')

mouse_drug_data_to_load = "../../Homework/Instructions/Pymaceuticals/data/mouse_drug_data.csv"
clinical_trial_data_to_load = "../../Homework/Instructions/Pymaceuticals/data/clinicaltrial_data.csv"

mouse_drug_data_df = pd.read_csv(mouse_drug_data_to_load)
clinical_trial_data_df = pd.read_csv(clinical_trial_data_to_load)

# %%
mouse_clinic_df = pd.merge(mouse_drug_data_df, clinical_trial_data_df, on="Mouse ID")

# %%
all_drugs = mouse_clinic_df['Drug'].unique()

colors = ["Red", "Blue", "Green", "Black", "gray", "yellow", "orange", "purple", "pink", "teal"]
makers = [".",",","o","*","s","p",":",">","^","x"]

def treatments(list_drugs):
    color = 0
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        means = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
        sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]
        x_axis = drug_df['Timepoint'].unique()
        standard_errors = [sem(s) for s in sample]
        
        fig, ax = plt.subplots()
        ax.errorbar(x_axis, means, standard_errors, fmt="o", color=colors[color], linestyle=':', linewidth=0.5)
        ax.grid(color='gray', linestyle='-', linewidth=0.2)
        ax.set_xlabel("Timepoint")
        ax.set_ylabel("Tumor Volume (mm3)")
        ax.set_title(f"Effects of {drug} on Test Subjects")
        
        color +=1

# %%
# treatments(all_drugs)

# %%
drug_list = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']
colors = ["Red", "Blue", "Green", "Black"]
makers = ["o","^","s","d"]

def treatments(list_drugs):
    color = 0
    marker = 0
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        means = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
        sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]
        x_axis = drug_df['Timepoint'].unique()
        standard_errors = [sem(s) for s in sample]
        
        plt.errorbar(x_axis, means, standard_errors, fmt=makers[marker], color=colors[color], linestyle='--', linewidth=0.5)
        plt.grid(color='gray', linestyle='-', linewidth=0.2)
        plt.title("Turmor Response to Treatment")
        plt.xlabel("Time (Days)")
        plt.ylabel("Tumor Volume (mm3)")
        plt.figlegend(drug_list, bbox_to_anchor=(0.23, 0.1, 0.1, 0.8))
        
        color +=1
        marker +=1

# %%
treatments(drug_list)

# %%
# def survival(list_drugs):
#     color = 0
#     marker = 0
#     for drug in list_drugs:
#         drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
#         times = drug_df['Timepoint'].unique()
#         means = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
#         sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]
#         x_axis = drug_df['Timepoint'].unique()
#         standard_errors = [sem(s) for s in sample]
        
#         plt.errorbar(x_axis, means, standard_errors, fmt=makers[marker], color=colors[color], linestyle='--', linewidth=0.5)
#         plt.grid(color='gray', linestyle='-', linewidth=0.2)
#         plt.title("Turmor Response to Treatment")
#         plt.xlabel("Time (Days)")
#         plt.ylabel("Tumor Volume (mm3)")
#         plt.figlegend(all_drugs, loc='best')
#         color +=1
#         marker +=1

# %%
drug_list = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']
colors = ["Red", "Blue", "Green", "Black"]
makers = ["o","^","s","d"]

def survival(list_drugs):
    color = 0
    marker = 0
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        num_of_mice = drug_df['Mouse ID'].nunique()
        num_of_mice_per_day = drug_df['Timepoint'].value_counts().tolist()
        survival_rate = [(x / num_of_mice)*100 for x in num_of_mice_per_day]
        sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]

        x_axis = drug_df['Timepoint'].unique()
        standard_errors = [sem(s) for s in sample]
        
        plt.plot(x_axis, survival_rate, marker=makers[marker], color=colors[color], linestyle='--', linewidth=0.5)
        plt.grid(color='gray', linestyle='-', linewidth=0.2)
        plt.title("Survival During Treatment")
        plt.xlabel("Time (Days)")
        plt.ylabel("Survival Rate (%)")
        plt.ylim(31,105,10)
        plt.figlegend(drug_list, bbox_to_anchor=(0.24, 0.29, 0.1, 0.1))
        
        color +=1
        marker +=1

# %%
survival(drug_list)

# %%
drug_list = ['Placebo']
colors = ["Black"]
makers = ["d"]

def survival(list_drugs):
    color = 0
    marker = 0
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        num_of_mice = drug_df['Mouse ID'].nunique()
        num_of_mice_per_day = drug_df['Timepoint'].value_counts().tolist()
        survival_rate = [(x / num_of_mice)*100 for x in num_of_mice_per_day]
        sample = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]

        x_axis = drug_df['Timepoint'].unique()
        standard_errors = [sem(s) for s in sample]
        
        plt.plot(x_axis, survival_rate, marker=makers[marker], color=colors[color], linestyle='--', linewidth=0.5)
        plt.grid(color='gray', linestyle='-', linewidth=0.2)
        plt.title("Survival During Treatment")
        plt.xlabel("Time (Days)")
        plt.ylabel("Survival Rate (%)")
        plt.ylim(31,105,10)
        plt.figlegend(drug_list, bbox_to_anchor=(0.24, 0.29, 0.1, 0.1))
        
        color +=1
        marker +=1

# %%
survival(drug_list)

# %%
cap_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == 'Capomulin']

times = cap_df['Timepoint'].unique()
means = [cap_df.loc[cap_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
sample = [cap_df.loc[cap_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]

# %%
1 - (means[9]/means[0])
# Out:
# 0.19475302667894168

# %%
inf_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == 'Infubinol']

times_2 = inf_df['Timepoint'].unique()
means_2 = [inf_df.loc[inf_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
sample_2 = [inf_df.loc[inf_df['Timepoint'] == (time)]['Tumor Volume (mm3)'] for time in times]

# %%
(means_2[9]/means_2[0]),(means_2[(len(means_2)-1)]/means_2[0])
# Out:
# (1.4612347172785187, 1.4612347172785187)

# %%
drug_list = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']

percentages = []

def tumor_growth(list_drugs):
    percentages = []
    x = -0.6
    for drug in list_drugs:
        drug_df = mouse_clinic_df.loc[mouse_clinic_df['Drug'] == (drug)]
        times = drug_df['Timepoint'].unique()
        test_means = [drug_df.loc[drug_df['Timepoint'] == (time)]['Tumor Volume (mm3)'].mean() for time in times]
        percentage_change = ((test_means[(len(test_means)-1)]/test_means[0])*100)-100
        
        if percentage_change >= 0:
            color = 'red'
            y = 5
        else:
            color = 'green'
            y = -8

        plt.bar(drug, percentage_change, color=(color), width= -1, align='edge')
        plt.grid(color='gray', linestyle='-', linewidth=0.5)
        plt.ylim(-30,70,20)
        plt.title("Tumor Change Over 45 Day Treatment")
        plt.ylabel("Percentage Tumor Volume Change")
        plt.text(x,y, s=(f"{(round(percentage_change))}%"), color='white')
        x += 1

# %%
tumor_growth(drug_list)
